# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanputta/RA-25/blob/main/YOLO_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Face Mask Detector
# In this workshop, we'll build an object detection model using the YOLO (You Only Look Once) algorithm, a highly efficient and accurate ML algorithm that processes images using a single pass of a neural network.
#
# We will be building an AI face mask detector to demonstrate the real-world implementations (ie. during the COVID-19 pandemic) of YOLO and CV machine learning models overall. [This](https://www.kaggle.com/datasets/andrewmvd/face-mask-detection/code?datasetId=667889&sortBy=voteCount) face mask image dataset from Kaggle will serve as both our training and validation data.

# %% [markdown]
# Run this block to ensure that the selected runtime is a NVIDIA Tesla T4 GPU. If not, go to Runtime —> Change runtime type and select T4 GPU under Hardware accelerator.

# %%
# !nvidia-smi
# Out:
# Wed Feb 18 21:20:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ##1. Preparation
# First, gather and label the data necessary for the model. For the purpose of this workshop, the data has already been pre-processed. Colab has a useful feature that allows you to directly access Kaggle datasets from your notebook, so run the following block to import our dataset.

# %%
from google.colab import drive
import kagglehub

drive.mount('/content/drive')
path = kagglehub.dataset_download("andrewmvd/face-mask-detection")

# Display the path to the Kaggle dataset within our notebook
print(path)
# Out:
# Mounted at /content/drive
# Using Colab cache for faster access to the 'face-mask-detection' dataset.
# /kaggle/input/face-mask-detection

# %% [markdown]
# ###1.1 Copy dataset
# Copy the data from our specified path into our desired dataset folder.

# %%
# !cp -a /kaggle/input/face-mask-detection/ /content/

# %% [markdown]
# ###1.2 Convert to .txt
# Convert the annotations (labels) into .txt format, since Ultralytics can only read plain text files, using this [PASCAL VOC to YOLO label converter](https://github.com/pylabel-project/pylabel).

# %%
# !pip install pylabel
from pylabel import importer
dataset = importer.ImportVOC(path='/content/face-mask-detection/annotations')
dataset.export.ExportToYoloV5()
# Out:
# Collecting pylabel
#   Downloading pylabel-0.1.55-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pylabel) (2.2.2)
# Collecting bbox-visualizer (from pylabel)
#   Downloading bbox_visualizer-0.3.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pylabel) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from pylabel) (4.13.0.92)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pylabel) (1.6.1)
# Collecting jupyter-bbox-widget (from pylabel)
#   Downloading jupyter_bbox_widget-0.6.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pylabel) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pylabel) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from bbox-visualizer->pylabel) (2.0.2)
# Requirement already satisfied: anywidget>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-bbox-widget->pylabel) (0.9.21)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pylabel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pylabel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pylabel) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pylabel) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pylabel) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pylabel) (3.6.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in /usr/local/lib/python3.12/dist-packages (from anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (7.7.1)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.15.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pylabel) (1.17.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.0.16)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (6.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (5.9.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.8.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.11)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.4.0)
# Downloading pylabel-0.1.55-py3-none-any.whl (27 kB)
# Downloading bbox_visualizer-0.3.0-py3-none-any.whl (10 kB)
# Downloading jupyter_bbox_widget-0.6.0-py3-none-any.whl (24 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.9 MB/s eta 0:00:00
# Installing collected packages: jedi, bbox-visualizer, jupyter-bbox-widget, pylabel
# Successfully installed bbox-visualizer-0.3.0 jedi-0.19.2 jupyter-bbox-widget-0.6.0 pylabel-0.1.55
# Importing VOC files...: 100%|██████████| 853/853 [00:00<00:00, 3883.52it/s]
# Exporting YOLO files...: 100%|██████████| 853/853 [00:01<00:00, 586.09it/s]
# ['training/dataset.yaml',
#  'training/labels/maksssksksss13.txt',
#  'training/labels/maksssksksss795.txt',
#  'training/labels/maksssksksss799.txt',
#  'training/labels/maksssksksss784.txt',
#  'training/labels/maksssksksss167.txt',
#  'training/labels/maksssksksss779.txt',
#  'training/labels/maksssksksss722.txt',
#  'training/labels/maksssksksss615.txt',
#  'training/labels/maksssksksss306.txt',
#  'training/labels/maksssksksss313.txt',
#  'training/labels/maksssksksss707.txt',
#  'training/labels/maksssksksss688.txt',
#  'training/labels/maksssksksss337.txt',
#  'training/labels/maksssksksss328.txt',
#  'training/labels/maksssksksss53.txt',
#  'training/labels/maksssksksss238.txt',
#  'training/labels/maksssksksss443.txt',
#  'training/labels/maksssksksss314.txt',
#  'training/labels/maksssksksss7.txt',
#  'training/labels/maksssksksss240.txt',
#  'training/labels/maksssksksss696.txt',
#  'training/labels/maksssksksss280.txt',
#  'training/labels/maksssksksss311.txt',
#  'training/labels/maksssksksss505.txt',
#  'training/labels/maksssksksss189.txt',
#  'training/labels/maksssksksss494.txt',
#  'training/labels/maksssksksss801.txt',
#  'training/labels/maksssksksss497.txt',
#  'training/labels/maksssksksss772.txt',
#  'training/labels/maksssksksss287.txt',
#  'training/labels/maksssksksss296.txt',
#  'training/labels/maksssksksss128.txt',
#  'training/labels/maksssksksss642.txt',
#  'training/labels/maksssksksss483.txt',
#  'training/labels/maksssksksss172.txt',
#  'training/labels/maksssksksss367.txt',
#  'training/labels/maksssksksss694.txt',
#  'training/labels/maksssksksss665.txt',
#  'training/labels/maksssksksss226.txt',
#  'training/labels/maksssksksss465.txt',
#  'training/labels/maksssksksss70.txt',
#  'training/labels/maksssksksss298.txt',
#  'training/labels/maksssksksss187.txt',
#  'training/labels/maksssksksss411.txt',
#  'training/labels/maksssksksss739.txt',
#  'training/labels/maksssksksss740.txt',
#  'training/labels/maksssksksss567.txt',
#  'training/labels/maksssksksss531.txt',
#  'training/labels/maksssksksss75.txt',
#  'training/labels/maksssksksss335.txt',
#  'training/labels/maksssksksss235.txt',
#  'training/labels/maksssksksss679.txt',
#  'training/labels/maksssksksss142.txt',
#  'training/labels/maksssksksss492.txt',
#  'training/labels/maksssksksss338.txt',
#  'training/labels/maksssksksss807.txt',
#  'training/labels/maksssksksss183.txt',
#  'training/labels/maksssksksss302.txt',
#  'training/labels/maksssksksss616.txt',
#  'training/labels/maksssksksss548.txt',
#  'training/labels/maksssksksss64.txt',
#  'training/labels/maksssksksss695.txt',
#  'training/labels/maksssksksss455.txt',
#  'training/labels/maksssksksss476.txt',
#  'training/labels/maksssksksss101.txt',
#  'training/labels/maksssksksss326.txt',
#  'training/labels/maksssksksss557.txt',
#  'training/labels/maksssksksss230.txt',
#  'training/labels/maksssksksss480.txt',
#  'training/labels/maksssksksss10.txt',
#  'training/labels/maksssksksss721.txt',
#  'training/labels/maksssksksss2.txt',
#  'training/labels/maksssksksss93.txt',
#  'training/labels/maksssksksss750.txt',
#  'training/labels/maksssksksss726.txt',
#  'training/labels/maksssksksss765.txt',
#  'training/labels/maksssksksss785.txt',
#  'training/labels/maksssksksss540.txt',
#  'training/labels/maksssksksss49.txt',
#  'training/labels/maksssksksss260.txt',
#  'training/labels/maksssksksss659.txt',
#  'training/labels/maksssksksss175.txt',
#  'training/labels/maksssksksss553.txt',
#  'training/labels/maksssksksss830.txt',
#  'training/labels/maksssksksss24.txt',
#  'training/labels/maksssksksss353.txt',
#  'training/labels/maksssksksss437.txt',
#  'training/labels/maksssksksss180.txt',
#  'training/labels/maksssksksss351.txt',
#  'training/labels/maksssksksss125.txt',
#  'training/labels/maksssksksss245.txt',
#  'training/labels/maksssksksss610.txt',
#  'training/labels/maksssksksss138.txt',
#  'training/labels/maksssksksss77.txt',
#  'training/labels/maksssksksss751.txt',
#  'training/labels/maksssksksss496.txt',
#  'training/labels/maksssksksss27.txt',
#  'training/labels/maksssksksss676.txt',
#  'training/labels/maksssksksss386.txt',
#  'training/labels/maksssksksss561.txt',
#  'training/labels/maksssksksss559.txt',
#  'training/labels/maksssksksss622.txt',
#  'training/labels/maksssksksss545.txt',
#  'training/labels/maksssksksss234.txt',
#  'training/labels/maksssksksss666.txt',
#  'training/labels/maksssksksss822.txt',
#  'training/labels/maksssksksss479.txt',
#  'training/labels/maksssksksss723.txt',
#  'training/labels/maksssksksss34.txt',
#  'training/labels/maksssksksss533.txt',
#  'training/labels/maksssksksss375.txt',
#  'training/labels/maksssksksss50.txt',
#  'training/labels/maksssksksss293.txt',
#  'training/labels/maksssksksss102.txt',
#  'training/labels/maksssksksss165.txt',
#  'training/labels/maksssksksss116.txt',
#  'training/labels/maksssksksss835.txt',
#  'training/labels/maksssksksss282.txt',
#  'training/labels/maksssksksss307.txt',
#  'training/labels/maksssksksss354.txt',
#  'training/labels/maksssksksss265.txt',
#  'training/labels/maksssksksss791.txt',
#  'training/labels/maksssksksss161.txt',
#  'training/labels/maksssksksss151.txt',
#  'training/labels/maksssksksss261.txt',
#  'training/labels/maksssksksss725.txt',
#  'training/labels/maksssksksss407.txt',
#  'training/labels/maksssksksss818.txt',
#  'training/labels/maksssksksss514.txt',
#  'training/labels/maksssksksss169.txt',
#  'training/labels/maksssksksss565.txt',
#  'training/labels/maksssksksss254.txt',
#  'training/labels/maksssksksss773.txt',
#  'training/labels/maksssksksss120.txt',
#  'training/labels/maksssksksss729.txt',
#  'training/labels/maksssksksss227.txt',
#  'training/labels/maksssksksss359.txt',
#  'training/labels/maksssksksss534.txt',
#  'training/labels/maksssksksss46.txt',
#  'training/labels/maksssksksss47.txt',
#  'training/labels/maksssksksss135.txt',
#  'training/labels/maksssksksss74.txt',
#  'training/labels/maksssksksss303.txt',
#  'training/labels/maksssksksss25.txt',
#  'training/labels/maksssksksss209.txt',
#  'training/labels/maksssksksss521.txt',
#  'training/labels/maksssksksss814.txt',
#  'training/labels/maksssksksss678.txt',
#  'training/labels/maksssksksss482.txt',
#  'training/labels/maksssksksss129.txt',
#  'training/labels/maksssksksss452.txt',
#  'training/labels/maksssksksss136.txt',
#  'training/labels/maksssksksss398.txt',
#  'training/labels/maksssksksss705.txt',
#  'training/labels/maksssksksss806.txt',
#  'training/labels/maksssksksss294.txt',
#  'training/labels/maksssksksss515.txt',
#  'training/labels/maksssksksss178.txt',
#  'training/labels/maksssksksss58.txt',
#  'training/labels/maksssksksss549.txt',
#  'training/labels/maksssksksss0.txt',
#  'training/labels/maksssksksss376.txt',
#  'training/labels/maksssksksss83.txt',
#  'training/labels/maksssksksss446.txt',
#  'training/labels/maksssksksss429.txt',
#  'training/labels/maksssksksss204.txt',
#  'training/labels/maksssksksss202.txt',
#  'training/labels/maksssksksss273.txt',
#  'training/labels/maksssksksss80.txt',
#  'training/labels/maksssksksss212.txt',
#  'training/labels/maksssksksss344.txt',
#  'training/labels/maksssksksss827.txt',
#  'training/labels/maksssksksss738.txt',
#  'training/labels/maksssksksss416.txt',
#  'training/labels/maksssksksss627.txt',
#  'training/labels/maksssksksss763.txt',
#  'training/labels/maksssksksss377.txt',
#  'training/labels/maksssksksss231.txt',
#  'training/labels/maksssksksss538.txt',
#  'training/labels/maksssksksss54.txt',
#  'training/labels/maksssksksss716.txt',
#  'training/labels/maksssksksss590.txt',
#  'training/labels/maksssksksss758.txt',
#  'training/labels/maksssksksss535.txt',
#  'training/labels/maksssksksss735.txt',
#  'training/labels/maksssksksss412.txt',
#  'training/labels/maksssksksss52.txt',
#  'training/labels/maksssksksss427.txt',
#  'training/labels/maksssksksss220.txt',
#  'training/labels/maksssksksss439.txt',
#  'training/labels/maksssksksss601.txt',
#  'training/labels/maksssksksss685.txt',
#  'training/labels/maksssksksss131.txt',
#  'training/labels/maksssksksss349.txt',
#  'training/labels/maksssksksss486.txt',
#  'training/labels/maksssksksss811.txt',
#  'training/labels/maksssksksss670.txt',
#  'training/labels/maksssksksss30.txt',
#  'training/labels/maksssksksss474.txt',
#  'training/labels/maksssksksss23.txt',
#  'training/labels/maksssksksss775.txt',
#  'training/labels/maksssksksss844.txt',
#  'training/labels/maksssksksss502.txt',
#  'training/labels/maksssksksss825.txt',
#  'training/labels/maksssksksss360.txt',
#  'training/labels/maksssksksss56.txt',
#  'training/labels/maksssksksss392.txt',
#  'training/labels/maksssksksss544.txt',
#  'training/labels/maksssksksss623.txt',
#  'training/labels/maksssksksss680.txt',
#  'training/labels/maksssksksss516.txt',
#  'training/labels/maksssksksss525.txt',
#  'training/labels/maksssksksss139.txt',
#  'training/labels/maksssksksss242.txt',
#  'training/labels/maksssksksss12.txt',
#  'training/labels/maksssksksss380.txt',
#  'training/labels/maksssksksss571.txt',
#  'training/labels/maksssksksss450.txt',
#  'training/labels/maksssksksss652.txt',
#  'training/labels/maksssksksss841.txt',
#  'training/labels/maksssksksss628.txt',
#  'training/labels/maksssksksss322.txt',
#  'training/labels/maksssksksss346.txt',
#  'training/labels/maksssksksss700.txt',
#  'training/labels/maksssksksss782.txt',
#  'training/labels/maksssksksss96.txt',
#  'training/labels/maksssksksss650.txt',
#  'training/labels/maksssksksss371.txt',
#  'training/labels/maksssksksss246.txt',
#  'training/labels/maksssksksss646.txt',
#  'training/labels/maksssksksss667.txt',
#  'training/labels/maksssksksss106.txt',
#  'training/labels/maksssksksss203.txt',
#  'training/labels/maksssksksss162.txt',
#  'training/labels/maksssksksss532.txt',
#  'training/labels/maksssksksss684.txt',
#  'training/labels/maksssksksss196.txt',
#  'training/labels/maksssksksss456.txt',
#  'training/labels/maksssksksss97.txt',
#  'training/labels/maksssksksss820.txt',
#  'training/labels/maksssksksss605.txt',
#  'training/labels/maksssksksss473.txt',
#  'training/labels/maksssksksss618.txt',
#  'training/labels/maksssksksss682.txt',
#  'training/labels/maksssksksss406.txt',
#  'training/labels/maksssksksss71.txt',
#  'training/labels/maksssksksss42.txt',
#  'training/labels/maksssksksss461.txt',
#  'training/labels/maksssksksss79.txt',
#  'training/labels/maksssksksss414.txt',
#  'training/labels/maksssksksss577.txt',
#  'training/labels/maksssksksss422.txt',
#  'training/labels/maksssksksss629.txt',
#  'training/labels/maksssksksss575.txt',
#  'training/labels/maksssksksss118.txt',
#  'training/labels/maksssksksss851.txt',
#  'training/labels/maksssksksss832.txt',
#  'training/labels/maksssksksss99.txt',
#  'training/labels/maksssksksss1.txt',
#  'training/labels/maksssksksss518.txt',
#  'training/labels/maksssksksss190.txt',
#  'training/labels/maksssksksss459.txt',
#  'training/labels/maksssksksss334.txt',
#  'training/labels/maksssksksss319.txt',
#  'training/labels/maksssksksss389.txt',
#  'training/labels/maksssksksss205.txt',
#  'training/labels/maksssksksss340.txt',
#  'training/labels/maksssksksss633.txt',
#  'training/labels/maksssksksss122.txt',
#  'training/labels/maksssksksss267.txt',
#  'training/labels/maksssksksss400.txt',
#  'training/labels/maksssksksss137.txt',
#  'training/labels/maksssksksss582.txt',
#  'training/labels/maksssksksss519.txt',
#  'training/labels/maksssksksss396.txt',
#  'training/labels/maksssksksss211.txt',
#  'training/labels/maksssksksss573.txt',
#  'training/labels/maksssksksss275.txt',
#  'training/labels/maksssksksss108.txt',
#  'training/labels/maksssksksss192.txt',
#  'training/labels/maksssksksss563.txt',
#  'training/labels/maksssksksss268.txt',
#  'training/labels/maksssksksss664.txt',
#  'training/labels/maksssksksss797.txt',
#  'training/labels/maksssksksss341.txt',
#  'training/labels/maksssksksss9.txt',
#  'training/labels/maksssksksss599.txt',
#  'training/labels/maksssksksss66.txt',
#  'training/labels/maksssksksss506.txt',
#  'training/labels/maksssksksss546.txt',
#  'training/labels/maksssksksss357.txt',
#  'training/labels/maksssksksss828.txt',
#  'training/labels/maksssksksss431.txt',
#  'training/labels/maksssksksss84.txt',
#  'training/labels/maksssksksss385.txt',
#  'training/labels/maksssksksss500.txt',
#  'training/labels/maksssksksss63.txt',
#  'training/labels/maksssksksss126.txt',
#  'training/labels/maksssksksss393.txt',
#  'training/labels/maksssksksss638.txt',
#  'training/labels/maksssksksss301.txt',
#  'training/labels/maksssksksss144.txt',
#  'training/labels/maksssksksss838.txt',
#  'training/labels/maksssksksss107.txt',
#  'training/labels/maksssksksss73.txt',
#  'training/labels/maksssksksss166.txt',
#  'training/labels/maksssksksss612.txt',
#  'training/labels/maksssksksss179.txt',
#  'training/labels/maksssksksss509.txt',
#  'training/labels/maksssksksss285.txt',
#  'training/labels/maksssksksss419.txt',
#  'training/labels/maksssksksss257.txt',
#  'training/labels/maksssksksss737.txt',
#  'training/labels/maksssksksss804.txt',
#  'training/labels/maksssksksss394.txt',
#  'training/labels/maksssksksss20.txt',
#  'training/labels/maksssksksss105.txt',
#  'training/labels/maksssksksss458.txt',
#  'training/labels/maksssksksss308.txt',
#  'training/labels/maksssksksss4.txt',
#  'training/labels/maksssksksss755.txt',
#  'training/labels/maksssksksss653.txt',
#  'training/labels/maksssksksss810.txt',
#  'training/labels/maksssksksss170.txt',
#  'training/labels/maksssksksss121.txt',
#  'training/labels/maksssksksss339.txt',
#  'training/labels/maksssksksss754.txt',
#  'training/labels/maksssksksss730.txt',
#  'training/labels/maksssksksss693.txt',
#  'training/labels/maksssksksss711.txt',
#  'training/labels/maksssksksss401.txt',
#  'training/labels/maksssksksss243.txt',
#  'training/labels/maksssksksss576.txt',
#  'training/labels/maksssksksss146.txt',
#  'training/labels/maksssksksss761.txt',
#  'training/labels/maksssksksss467.txt',
#  'training/labels/maksssksksss233.txt',
#  'training/labels/maksssksksss718.txt',
#  'training/labels/maksssksksss836.txt',
#  'training/labels/maksssksksss792.txt',
#  'training/labels/maksssksksss22.txt',
#  'training/labels/maksssksksss645.txt',
#  'training/labels/maksssksksss805.txt',
#  'training/labels/maksssksksss364.txt',
#  'training/labels/maksssksksss604.txt',
#  'training/labels/maksssksksss587.txt',
#  'training/labels/maksssksksss580.txt',
#  'training/labels/maksssksksss103.txt',
#  'training/labels/maksssksksss812.txt',
#  'training/labels/maksssksksss668.txt',
#  'training/labels/maksssksksss569.txt',
#  'training/labels/maksssksksss781.txt',
#  'training/labels/maksssksksss19.txt',
#  'training/labels/maksssksksss426.txt',
#  'training/labels/maksssksksss619.txt',
#  'training/labels/maksssksksss26.txt',
#  'training/labels/maksssksksss793.txt',
#  'training/labels/maksssksksss36.txt',
#  'training/labels/maksssksksss517.txt',
#  'training/labels/maksssksksss821.txt',
#  'training/labels/maksssksksss403.txt',
#  'training/labels/maksssksksss712.txt',
#  'training/labels/maksssksksss223.txt',
#  'training/labels/maksssksksss378.txt',
#  'training/labels/maksssksksss770.txt',
#  'training/labels/maksssksksss259.txt',
#  'training/labels/maksssksksss593.txt',
#  'training/labels/maksssksksss748.txt',
#  'training/labels/maksssksksss831.txt',
#  'training/labels/maksssksksss771.txt',
#  'training/labels/maksssksksss756.txt',
#  'training/labels/maksssksksss288.txt',
#  'training/labels/maksssksksss464.txt',
#  'training/labels/maksssksksss397.txt',
#  'training/labels/maksssksksss539.txt',
#  'training/labels/maksssksksss256.txt',
#  'training/labels/maksssksksss370.txt',
#  'training/labels/maksssksksss484.txt',
#  'training/labels/maksssksksss216.txt',
#  'training/labels/maksssksksss210.txt',
#  'training/labels/maksssksksss154.txt',
#  'training/labels/maksssksksss603.txt',
#  'training/labels/maksssksksss39.txt',
#  'training/labels/maksssksksss45.txt',
#  'training/labels/maksssksksss529.txt',
#  'training/labels/maksssksksss671.txt',
#  'training/labels/maksssksksss448.txt',
#  'training/labels/maksssksksss343.txt',
#  'training/labels/maksssksksss361.txt',
#  'training/labels/maksssksksss475.txt',
#  'training/labels/maksssksksss733.txt',
#  'training/labels/maksssksksss289.txt',
#  'training/labels/maksssksksss305.txt',
#  'training/labels/maksssksksss232.txt',
#  'training/labels/maksssksksss815.txt',
#  'training/labels/maksssksksss442.txt',
#  'training/labels/maksssksksss672.txt',
#  'training/labels/maksssksksss278.txt',
#  'training/labels/maksssksksss150.txt']

# %% [markdown]
# Clean up our file structure, replacing the .xml annotations with our converted .txt annotations in our `face-mask-detection` directory.

# %%
# We'll be creating our own YAML file with the correct formatting later
# !rm -f '/content/training/dataset.yaml'

# !rm -r '/content/face-mask-detection/annotations/'
# !mv '/content/training/labels/' '/content/face-mask-detection/labels/'

# Remove empty directory
# !rm -r '/content/training/'

# %% [markdown]
# ###1.3 Create folder structure
# Ultralytics, which will be used to train the YOLO model, requires a particular folder structure for its stored data:
#
# *   **Training** — Images used to train the model. Each epoch (iteration) of training, every image in this subset is passed through the model's neural network. The training algorithm then adjusts its weights to better fit the images, aka "learning" from the data.
# *   **Validation** — Images used to test the model's accuracy. The model analyzes images that it wasn't trained on (which are completely new to this version of the model) to determine how well it was trained at the end of each epoch.
#
# Each folder contains two sub-folders, one for images and one for labels. This keeps the actual images separate from the annotations. We'll be using a Python script (written by EdjeElectronics on GitHub) to randomly split our dataset into **training** (*80% of original*) and **validation** (*20% of original*) subsets.

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# !python train_val_split.py --datapath="/content/face-mask-detection" --train_pct=0.8
# Out:
# --2026-02-18 21:23:05--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘/content/train_val_split.py’
#
# /content/train_val_ 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2026-02-18 21:23:06 (57.4 MB/s) - ‘/content/train_val_split.py’ saved [3203/3203]
#
# Created folder at /content/data/train/images.
# Created folder at /content/data/train/labels.
# Created folder at /content/data/validation/images.
# Created folder at /content/data/validation/labels.
# Number of image files: 853
# Number of annotation files: 853
# Images moving to train: 682
# Images moving to validation: 171

# %% [markdown]
# ##2. Configure Training
# Install the Ultralytics library. Afterwards, import the `notes.json` and `classes.txt` files from the ML/AI shared drive into `face-mask-detection` to match the required folder structure.

# %%
# !pip install ultralytics
import yaml
import os
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.14-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.21.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.14-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.14 ultralytics-thop-2.0.18

# %%
'<import the necessary files in this cell>'

# %% [markdown]
# Define the function to construct the YAML file. This specifies the location of the training and validation data, as well as the model's classes. This cell:
#
# 1. Reads 'classes.txt' (part of the dataset zip file) to get the list of class names
# 2. Creates a dictionary containing the correct paths to folders, class names, and # of classes total
# 3. Writes data formatted in YAML to data.yaml

# %%
def create_yaml_file(classes_txt_path, data_yaml_path):

  # Get class names from classes.txt
  if not os.path.exists(classes_txt_path):
    print(f'classes.txt file not found. Please create a classes.txt labelmap and move it to {classes-txt_path}')
    return
  with open(classes_txt_path, 'r') as file:
    classes = []
    for line in file.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  class_num = len(classes)

  # Create dictionary
  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'num': class_num,
      'names': classes
  }

  # Format data to YAML and creates file
  with open(data_yaml_path, 'w') as file:
    yaml.dump(data, file, sort_keys=False)
  print(f'Created config file at {data_yaml_path}')

  return

# %% [markdown]
# Create the Ultralytics training configuration YAML file and print contents

# %%
# Define paths and create YAML file
classes_txt_path = '/content/face-mask-detection/classes.txt'
data_yaml_path = '/content/data.yaml'

create_yaml_file(classes_txt_path, data_yaml_path)

# Concatenates contents of YAML file to print statement
print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# Created config file at /content/data.yaml
#
# File contents:
#
# path: /content/data
# train: train/images
# val: validation/images
# num: 3
# names:
# - With mask
# - Without mask
# - Mask worn incorrectly

# %% [markdown]
# ##3. Train Model
# There are several important parameters to decide before running this model. These include 1) model architecture & size, 2) number of epochs, and 3) image resolution.
#
# *   **Model Architecture**: The latest YOLO model (as of Jan 2026) is YOLO26, but models like YOLO11 and YOLO8 are more mature and have more technical support. Finding a model that's small enough for the model's speed requirements yet accurate enough to detect objects properly is key.
# *   **# of Epochs**: Training your model with a lower # of epochs is faster, but yields a less accurate model. Training your model with a higher # of epochs, on the other hand, is slower but yields a more accurate model. *However, there is a # of epochs where you may ultimately overfit your model to the training data.*
# *   **Image Resolution**: Resolution is similar to the epochs parameter. Lower is faster but less accurate, while higher is slower but more accurate.
#
# For the purposes of this workshop, we'll be using YOLO26s, 40 epochs (> 200 images in the dataset), and 640x640 resolution. Read more about [YOLO models](https://docs.ultralytics.com/models/yolo26/#overview).

# %%
# !yolo detect train data=/content/data.yaml model=yolo11s.pt epochs=40 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 211.5MB/s 0.1s
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 45.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820569  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,428,953 parameters, 9,428,937 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 117.8MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3676.4±1322.0 MB/s, size: 417.9 KB)
# train: Scanning /content/data/train/labels... 682 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 682/682 986.0it/s 0.7s
# train: New cache created: /content/data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1637.0±2029.6 MB/s, size: 455.8 KB)
# val: Scanning /content/data/validation/labels... 171 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 171/171 488.6it/s 0.3s
# val: New cache created: /content/data/validation/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      4.66G      1.658      2.061      1.409         73        640: 100% ━━━━━━━━━━━━ 43/43 1.2it/s 37.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.7s/it 22.5s
#                    all        171        925      0.483      0.466      0.484      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      5.02G      1.279      1.001      1.115         83        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.7s
#                    all        171        925      0.512      0.573       0.54      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      5.08G      1.263       0.96      1.099         81        640: 100% ━━━━━━━━━━━━ 43/43 2.9it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5it/s 3.9s
#                    all        171        925      0.585      0.602      0.587       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      5.12G      1.216     0.8873      1.086         61        640: 100% ━━━━━━━━━━━━ 43/43 2.9it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.7s
#                    all        171        925      0.581      0.519      0.446      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      5.14G      1.192     0.8228      1.073         98        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.7s
#                    all        171        925      0.703      0.653      0.683       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40       5.2G       1.21     0.8024      1.072        101        640: 100% ━━━━━━━━━━━━ 43/43 2.7it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.1it/s 2.8s
#                    all        171        925      0.674      0.668      0.673      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      5.24G      1.147     0.7767      1.056         83        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.3it/s 2.6s
#                    all        171        925       0.71      0.643      0.683      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      5.28G      1.148     0.7411      1.057         54        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.9it/s 3.2s
#                    all        171        925      0.665      0.668       0.69      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40       5.3G      1.157     0.7232      1.052         80        640: 100% ━━━━━━━━━━━━ 43/43 2.7it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        171        925      0.765      0.706       0.75      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      5.36G      1.153     0.7157      1.044         46        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.4it/s 2.5s
#                    all        171        925      0.877      0.696      0.791      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40       5.4G      1.142     0.7191      1.046         52        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s
#                    all        171        925      0.738      0.739      0.753       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      5.44G      1.121     0.6884      1.038         87        640: 100% ━━━━━━━━━━━━ 43/43 2.7it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        171        925       0.81      0.676      0.745      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      5.46G      1.108     0.6593      1.023         61        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.1it/s 2.9s
#                    all        171        925      0.818      0.731      0.821      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      5.52G      1.079     0.6293       1.03         49        640: 100% ━━━━━━━━━━━━ 43/43 2.8it/s 15.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        171        925       0.82      0.689      0.795      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40
# image 150/171 /content/data/validation/images/maksssksksss783.png: 448x640 5 With masks, 9.5ms
# image 151/171 /content/data/validation/images/maksssksksss784.png: 384x640 8 With masks, 1 Mask worn incorrectly, 9.1ms
# image 152/171 /content/data/validation/images/maksssksksss793.png: 640x512 1 With mask, 10.5ms
# image 153/171 /content/data/validation/images/maksssksksss797.png: 416x640 7 With masks, 10.0ms
# image 154/171 /content/data/validation/images/maksssksksss80.png: 384x640 1 With mask, 9.1ms
# image 155/171 /content/data/validation/images/maksssksksss806.png: 384x640 6 With masks, 1 Mask worn incorrectly, 8.8ms
# image 156/171 /content/data/validation/images/maksssksksss807.png: 448x640 7 With masks, 10.3ms
# image 157/171 /content/data/validation/images/maksssksksss813.png: 640x512 2 With masks, 10.5ms
# image 158/171 /content/data/validation/images/maksssksksss815.png: 640x448 1 Without mask, 10.1ms
# image 159/171 /content/data/validation/images/maksssksksss82.png: 384x640 6 With masks, 9.1ms
# image 160/171 /content/data/validation/images/maksssksksss825.png: 384x640 4 With masks, 8.5ms
# image 161/171 /content/data/validation/images/maksssksksss826.png: 448x640 5 With masks, 10.1ms
# image 162/171 /content/data/validation/images/maksssksksss828.png: 640x512 1 With mask, 12.3ms
# image 163/171 /content/data/validation/images/maksssksksss841.png: 640x512 1 Mask worn incorrectly, 9.8ms
# image 164/171 /content/data/validation/images/maksssksksss843.png: 640x640 4 With masks, 12.9ms
# image 165/171 /content/data/validation/images/maksssksksss852.png: 640x448 1 Without mask, 1 Mask worn incorrectly, 10.1ms
# image 166/171 /content/data/validation/images/maksssksksss91.png: 384x640 3 With masks, 9.1ms
# image 167/171 /content/data/validation/images/maksssksksss94.png: 384x640 5 With masks, 1 Without mask, 1 Mask worn incorrectly, 8.5ms
# image 168/171 /content/data/validation/images/maksssksksss95.png: 640x512 1 Mask worn incorrectly, 10.4ms
# image 169/171 /content/data/validation/images/maksssksksss96.png: 448x640 2 With masks, 2 Mask worn incorrectlys, 10.0ms
# image 170/171 /content/data/validation/images/maksssksksss97.png: 640x512 1 With mask, 10.3ms
# image 171/171 /content/data/validation/images/maksssksksss98.png: 448x640 3 With masks, 10.0ms
# Speed: 1.9ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# Use the first 10 images and output the analysis results. There should be a box drawn around the object(s) of interest for each image.

# %%
# Python's glob module searches for file path names that match
# the pattern of Unix's shell rules
import glob

from IPython.display import Image, display
for path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=path, height=620))
  print('\n')

# %% [markdown]
# If the results seem off or inaccurate, you can ask me (Nam) to take a look at your copy of the notebook. In general though, these are a few steps you can take to check and change your model:
#
# *   Double-check your dataset to see if there are any labeling errors or contradictory examples
# *   Increase the number of training epochs
# *   Use a larger model size, such as YOLO26l, YOLO26xl, etc.
# *   Increase the dataset by adding more labeled images

# %% [markdown]
# ##5. Use Model
# Now that the model has been successfully trained and tested, you can actually try it out.

# %% [markdown]
# Some potential ideas to expand upon this model and incorporate into a larger program include an efficiency detector (based on studies determining the effectiveness of different types of face masks) or a "worn correctly" detector.
#
# *This is good practice to develop your own datasets and/or apply ML models into applications*.
